# %%
import numpy as np
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
X[:10]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)

# %% [markdown]
# ### scikit-learn中的StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
standardScaler = StandardScaler()

# %%
standardScaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
standardScaler.mean_
# Out:
# array([5.83303571, 3.09017857, 3.67410714, 1.16964286])

# %%
standardScaler.scale_
# Out:
# array([0.80516063, 0.42572623, 1.78319264, 0.77688013])

# %%
standardScaler.transform(X_train)
# Out:
# array([[-1.77981344,  0.25796256, -1.33138007, -1.24812416],
#        [-0.04102997, -1.15139386,  0.18275808,  0.03907571],
#        [ 0.57996413,  0.4928553 ,  0.57531241,  0.55395566],
#        [-0.78622289,  0.96264077, -1.21922169, -1.24812416],
#        [-0.53782525,  0.72774803, -1.21922169, -0.99068419],
#        [-1.5314158 ,  0.25796256, -1.27530088, -1.24812416],
#        [ 1.69775351,  0.25796256,  1.30434189,  0.81139564],
#        [ 0.95256059, -0.21182291,  0.40707484,  0.29651569],
#        [ 1.82195233, -0.44671565,  1.47257946,  0.81139564],
#        [-0.78622289,  0.72774803, -1.27530088, -1.24812416],
#        [ 0.70416295,  0.25796256,  0.91178756,  1.45499557],
#        [ 1.32515705,  0.25796256,  1.13610432,  1.45499557],
#        [ 1.07675941, -0.21182291,  0.85570836,  1.45499557],
#        [-1.03462052, -2.56075028, -0.09763788, -0.21836426],
#        [ 0.45576531,  0.72774803,  0.96786675,  1.45499557],
#        [ 0.57996413, -1.3862866 ,  0.68747079,  0.42523567],
#        [-1.03462052,  0.96264077, -1.33138007, -1.11940418],
#        [ 1.32515705,  0.02306982,  0.68747079,  0.42523567],
#        [ 0.70416295,  0.25796256,  0.46315403,  0.42523567],
#        [ 0.20736767, -2.09096481,  0.18275808, -0.21836426],
#        [ 1.44935587,  0.25796256,  0.57531241,  0.29651569],
#        [ 0.33156649, -1.15139386,  1.08002513,  0.29651569],
#        [ 0.70416295, -0.91650113,  0.91178756,  0.94011562],
#        [ 1.57355469, -0.21182291,  1.2482627 ,  1.1975556 ],
#        [ 1.07675941,  0.02306982,  0.40707484,  0.29651569],
#        [-1.03462052,  0.72774803, -1.1631425 , -0.99068419],
#        [-1.15881934,  0.02306982, -1.21922169, -1.24812416],
#        [ 0.08316885, -0.21182291,  0.79962917,  0.81139564],
#        [ 0.57996413, -1.85607207,  0.40707484,  0.1677957 ],
#        [-1.03462052, -0.21182291, -1.1631425 , -1.24812416],
#        [-0.28942761, -0.91650113,  0.29491646,  0.1677957 ],
#        [-0.16522879,  3.0766754 , -1.21922169, -0.99068419],
#        [-0.9104217 , -1.3862866 , -0.37803383, -0.08964428],
#        [ 0.82836177, -0.21182291,  0.85570836,  1.06883561],
#        [-1.15881934, -0.21182291, -1.27530088, -1.24812416],
#        [-0.9104217 ,  1.66731898, -0.99490493, -0.99068419],
#        [ 0.20736767, -0.91650113,  0.79962917,  0.55395566],
#        [ 0.33156649, -0.21182291,  0.51923322,  0.29651569],
#        [-1.03462052, -1.85607207, -0.20979626, -0.21836426],
#        [-0.9104217 ,  0.4928553 , -1.10706331, -0.8619642 ],
#        [-1.28301816, -0.21182291, -1.27530088, -1.37684415],
#        [-0.9104217 ,  1.66731898, -1.21922169, -1.11940418],
#        [-0.04102997,  2.13710445, -1.38745926, -1.24812416],
#        [-0.53782525,  0.72774803, -1.10706331, -1.24812416],
#        [-1.03462052,  0.25796256, -1.38745926, -1.24812416],
#        [-1.5314158 ,  0.02306982, -1.21922169, -1.24812416],
#        [-0.16522879, -0.21182291,  0.29491646,  0.03907571],
#        [-0.9104217 ,  0.96264077, -1.27530088, -1.11940418],
#        [-0.78622289, -0.91650113,  0.12667889,  0.29651569],
#        [-0.04102997, -0.68160839,  0.79962917,  1.58371556],
#        [-1.28301816,  0.72774803, -0.99490493, -1.24812416],
#        [-0.53782525,  1.90221172, -1.33138007, -0.99068419],
#        [ 0.33156649, -0.68160839,  0.18275808,  0.1677957 ],
#        [ 1.69775351,  1.19753351,  1.36042108,  1.71243555],
#        [ 0.70416295,  0.02306982,  1.02394594,  0.81139564],
#        [ 0.08316885, -0.21182291,  0.29491646,  0.42523567],
#        [-1.28301816,  0.72774803, -1.1631425 , -1.24812416],
#        [ 0.33156649, -0.68160839,  0.57531241,  0.03907571],
#        [ 0.95256059, -0.44671565,  0.51923322,  0.1677957 ],
#        [ 0.57996413,  0.72774803,  1.08002513,  1.58371556],
#        [-0.9104217 ,  0.96264077, -1.27530088, -1.24812416],
#        [ 0.20736767, -2.09096481,  0.74354998,  0.42523567],
#        [ 2.31874761, -1.15139386,  1.80905461,  1.45499557],
#        [-0.16522879,  1.66731898, -1.10706331, -1.11940418],
#        [ 1.32515705,  0.02306982,  0.79962917,  1.45499557],
#        [ 0.57996413, -0.68160839,  0.79962917,  0.42523567],
#        [ 0.57996413, -1.3862866 ,  0.74354998,  0.94011562],
#        [-0.41362643, -1.15139386,  0.40707484,  0.03907571],
#        [-1.5314158 ,  0.72774803, -1.27530088, -1.11940418],
#        [ 1.07675941, -0.21182291,  0.74354998,  0.68267565],
#        [-1.03462052,  0.4928553 , -1.27530088, -1.24812416],
#        [-0.78622289,  2.37199719, -1.21922169, -1.37684415],
#        [-0.16522879, -0.68160839,  0.46315403,  0.1677957 ],
#        [-0.16522879, -0.44671565,  0.29491646,  0.1677957 ],
#        [ 1.07675941,  0.4928553 ,  1.13610432,  1.1975556 ],
#        [-0.28942761, -1.3862866 ,  0.12667889, -0.08964428],
#        [ 0.57996413, -0.44671565,  1.08002513,  0.81139564],
#        [-0.9104217 ,  1.66731898, -1.1631425 , -1.24812416],
#        [ 1.07675941,  0.02306982,  1.08002513,  1.58371556],
#        [-1.28301816,  0.02306982, -1.1631425 , -1.24812416],
#        [-0.9104217 ,  1.43242624, -1.21922169, -0.99068419],
#        [ 0.70416295, -0.68160839,  1.08002513,  1.32627558],
#        [ 0.82836177, -0.21182291,  1.02394594,  0.81139564],
#        [ 1.69775351, -0.21182291,  1.19218351,  0.55395566],
#        [ 0.20736767, -0.21182291,  0.6313916 ,  0.81139564],
#        [ 0.70416295, -0.68160839,  1.08002513,  1.1975556 ],
#        [-0.41362643, -1.3862866 ,  0.18275808,  0.1677957 ],
#        [ 1.20095823,  0.25796256,  1.2482627 ,  1.45499557],
#        [ 1.07675941,  0.02306982,  0.57531241,  0.42523567],
#        [-1.15881934,  0.02306982, -1.21922169, -1.37684415],
#        [ 0.33156649, -0.44671565,  0.57531241,  0.29651569],
#        [ 0.82836177,  0.25796256,  0.79962917,  1.06883561],
#        [-1.28301816, -0.21182291, -1.27530088, -1.11940418],
#        [ 2.31874761, -0.68160839,  1.69689622,  1.06883561],
#        [ 0.82836177, -0.21182291,  1.19218351,  1.32627558],
#        [-0.53782525,  1.90221172, -1.10706331, -0.99068419],
#        [-1.5314158 ,  1.19753351, -1.49961764, -1.24812416],
#        [-0.66202407,  1.43242624, -1.21922169, -1.24812416],
#        [ 1.07675941,  0.4928553 ,  1.13610432,  1.71243555],
#        [ 0.20736767, -0.44671565,  0.46315403,  0.42523567],
#        [-0.16522879, -1.3862866 ,  0.74354998,  1.06883561],
#        [ 0.57996413, -0.91650113,  0.68747079,  0.81139564],
#        [-1.03462052,  1.19753351, -1.27530088, -1.24812416],
#        [-1.03462052,  0.96264077, -1.1631425 , -0.73324421],
#        [-1.15881934,  1.19753351, -1.27530088, -1.37684415],
#        [ 0.45576531, -0.68160839,  0.6313916 ,  0.81139564],
#        [-1.77981344, -0.21182291, -1.33138007, -1.24812416],
#        [-0.9104217 ,  0.72774803, -1.21922169, -1.24812416],
#        [ 2.31874761, -0.21182291,  1.36042108,  1.45499557],
#        [ 0.70416295, -0.44671565,  0.35099565,  0.1677957 ],
#        [-0.28942761, -0.21182291,  0.46315403,  0.42523567],
#        [-1.15881934, -1.62117934, -0.20979626, -0.21836426]])

# %%
X_train
# Out:
# array([[4.4, 3.2, 1.3, 0.2],
#        [5.8, 2.6, 4. , 1.2],
#        [6.3, 3.3, 4.7, 1.6],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [4.6, 3.2, 1.4, 0.2],
#        [7.2, 3.2, 6. , 1.8],
#        [6.6, 3. , 4.4, 1.4],
#        [7.3, 2.9, 6.3, 1.8],
#        [5.2, 3.4, 1.4, 0.2],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.9, 3.2, 5.7, 2.3],
#        [6.7, 3. , 5.2, 2.3],
#        [5. , 2. , 3.5, 1. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [5. , 3.5, 1.3, 0.3],
#        [6.9, 3.1, 4.9, 1.5],
#        [6.4, 3.2, 4.5, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [7. , 3.2, 4.7, 1.4],
#        [6.1, 2.6, 5.6, 1.4],
#        [6.4, 2.7, 5.3, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.7, 3.1, 4.4, 1.4],
#        [5. , 3.4, 1.6, 0.4],
#        [4.9, 3.1, 1.5, 0.2],
#        [5.9, 3. , 5.1, 1.8],
#        [6.3, 2.3, 4.4, 1.3],
#        [5. , 3. , 1.6, 0.2],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.1, 2.5, 3. , 1.1],
#        [6.5, 3. , 5.2, 2. ],
#        [4.9, 3. , 1.4, 0.2],
#        [5.1, 3.8, 1.9, 0.4],
#        [6. , 2.7, 5.1, 1.6],
#        [6.1, 3. , 4.6, 1.4],
#        [5. , 2.3, 3.3, 1. ],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3. , 1.4, 0.1],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.8, 4. , 1.2, 0.2],
#        [5.4, 3.4, 1.7, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.7, 3. , 4.2, 1.2],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.8, 2.8, 5.1, 2.4],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.4, 3.9, 1.3, 0.4],
#        [6.1, 2.8, 4. , 1.3],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.4, 3.1, 5.5, 1.8],
#        [5.9, 3. , 4.2, 1.5],
#        [4.8, 3.4, 1.6, 0.2],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.6, 2.9, 4.6, 1.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [5.1, 3.5, 1.4, 0.2],
#        [6. , 2.2, 5. , 1.5],
#        [7.7, 2.6, 6.9, 2.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [6.9, 3.1, 5.1, 2.3],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.3, 2.5, 5. , 1.9],
#        [5.5, 2.6, 4.4, 1.2],
#        [4.6, 3.4, 1.4, 0.3],
#        [6.7, 3. , 5. , 1.7],
#        [5. , 3.3, 1.4, 0.2],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.7, 2.8, 4.5, 1.3],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.7, 3.3, 5.7, 2.1],
#        [5.6, 2.5, 3.9, 1.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [5.1, 3.8, 1.6, 0.2],
#        [6.7, 3.1, 5.6, 2.4],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.5, 3. , 5.5, 1.8],
#        [7.2, 3. , 5.8, 1.6],
#        [6. , 3. , 4.8, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [5.5, 2.5, 4. , 1.3],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.1, 4.7, 1.5],
#        [4.9, 3.1, 1.5, 0.1],
#        [6.1, 2.9, 4.7, 1.4],
#        [6.5, 3.2, 5.1, 2. ],
#        [4.8, 3. , 1.4, 0.3],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.5, 3. , 5.8, 2.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [6.7, 3.3, 5.7, 2.5],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.5, 5. , 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [5. , 3.6, 1.4, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [4.9, 3.6, 1.4, 0.1],
#        [6.2, 2.8, 4.8, 1.8],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [7.7, 3. , 6.1, 2.3],
#        [6.4, 2.9, 4.3, 1.3],
#        [5.6, 3. , 4.5, 1.5],
#        [4.9, 2.4, 3.3, 1. ]])

# %%
X_train = standardScaler.transform(X_train)

# %%
X_train
# Out:
# array([[-1.77981344,  0.25796256, -1.33138007, -1.24812416],
#        [-0.04102997, -1.15139386,  0.18275808,  0.03907571],
#        [ 0.57996413,  0.4928553 ,  0.57531241,  0.55395566],
#        [-0.78622289,  0.96264077, -1.21922169, -1.24812416],
#        [-0.53782525,  0.72774803, -1.21922169, -0.99068419],
#        [-1.5314158 ,  0.25796256, -1.27530088, -1.24812416],
#        [ 1.69775351,  0.25796256,  1.30434189,  0.81139564],
#        [ 0.95256059, -0.21182291,  0.40707484,  0.29651569],
#        [ 1.82195233, -0.44671565,  1.47257946,  0.81139564],
#        [-0.78622289,  0.72774803, -1.27530088, -1.24812416],
#        [ 0.70416295,  0.25796256,  0.91178756,  1.45499557],
#        [ 1.32515705,  0.25796256,  1.13610432,  1.45499557],
#        [ 1.07675941, -0.21182291,  0.85570836,  1.45499557],
#        [-1.03462052, -2.56075028, -0.09763788, -0.21836426],
#        [ 0.45576531,  0.72774803,  0.96786675,  1.45499557],
#        [ 0.57996413, -1.3862866 ,  0.68747079,  0.42523567],
#        [-1.03462052,  0.96264077, -1.33138007, -1.11940418],
#        [ 1.32515705,  0.02306982,  0.68747079,  0.42523567],
#        [ 0.70416295,  0.25796256,  0.46315403,  0.42523567],
#        [ 0.20736767, -2.09096481,  0.18275808, -0.21836426],
#        [ 1.44935587,  0.25796256,  0.57531241,  0.29651569],
#        [ 0.33156649, -1.15139386,  1.08002513,  0.29651569],
#        [ 0.70416295, -0.91650113,  0.91178756,  0.94011562],
#        [ 1.57355469, -0.21182291,  1.2482627 ,  1.1975556 ],
#        [ 1.07675941,  0.02306982,  0.40707484,  0.29651569],
#        [-1.03462052,  0.72774803, -1.1631425 , -0.99068419],
#        [-1.15881934,  0.02306982, -1.21922169, -1.24812416],
#        [ 0.08316885, -0.21182291,  0.79962917,  0.81139564],
#        [ 0.57996413, -1.85607207,  0.40707484,  0.1677957 ],
#        [-1.03462052, -0.21182291, -1.1631425 , -1.24812416],
#        [-0.28942761, -0.91650113,  0.29491646,  0.1677957 ],
#        [-0.16522879,  3.0766754 , -1.21922169, -0.99068419],
#        [-0.9104217 , -1.3862866 , -0.37803383, -0.08964428],
#        [ 0.82836177, -0.21182291,  0.85570836,  1.06883561],
#        [-1.15881934, -0.21182291, -1.27530088, -1.24812416],
#        [-0.9104217 ,  1.66731898, -0.99490493, -0.99068419],
#        [ 0.20736767, -0.91650113,  0.79962917,  0.55395566],
#        [ 0.33156649, -0.21182291,  0.51923322,  0.29651569],
#        [-1.03462052, -1.85607207, -0.20979626, -0.21836426],
#        [-0.9104217 ,  0.4928553 , -1.10706331, -0.8619642 ],
#        [-1.28301816, -0.21182291, -1.27530088, -1.37684415],
#        [-0.9104217 ,  1.66731898, -1.21922169, -1.11940418],
#        [-0.04102997,  2.13710445, -1.38745926, -1.24812416],
#        [-0.53782525,  0.72774803, -1.10706331, -1.24812416],
#        [-1.03462052,  0.25796256, -1.38745926, -1.24812416],
#        [-1.5314158 ,  0.02306982, -1.21922169, -1.24812416],
#        [-0.16522879, -0.21182291,  0.29491646,  0.03907571],
#        [-0.9104217 ,  0.96264077, -1.27530088, -1.11940418],
#        [-0.78622289, -0.91650113,  0.12667889,  0.29651569],
#        [-0.04102997, -0.68160839,  0.79962917,  1.58371556],
#        [-1.28301816,  0.72774803, -0.99490493, -1.24812416],
#        [-0.53782525,  1.90221172, -1.33138007, -0.99068419],
#        [ 0.33156649, -0.68160839,  0.18275808,  0.1677957 ],
#        [ 1.69775351,  1.19753351,  1.36042108,  1.71243555],
#        [ 0.70416295,  0.02306982,  1.02394594,  0.81139564],
#        [ 0.08316885, -0.21182291,  0.29491646,  0.42523567],
#        [-1.28301816,  0.72774803, -1.1631425 , -1.24812416],
#        [ 0.33156649, -0.68160839,  0.57531241,  0.03907571],
#        [ 0.95256059, -0.44671565,  0.51923322,  0.1677957 ],
#        [ 0.57996413,  0.72774803,  1.08002513,  1.58371556],
#        [-0.9104217 ,  0.96264077, -1.27530088, -1.24812416],
#        [ 0.20736767, -2.09096481,  0.74354998,  0.42523567],
#        [ 2.31874761, -1.15139386,  1.80905461,  1.45499557],
#        [-0.16522879,  1.66731898, -1.10706331, -1.11940418],
#        [ 1.32515705,  0.02306982,  0.79962917,  1.45499557],
#        [ 0.57996413, -0.68160839,  0.79962917,  0.42523567],
#        [ 0.57996413, -1.3862866 ,  0.74354998,  0.94011562],
#        [-0.41362643, -1.15139386,  0.40707484,  0.03907571],
#        [-1.5314158 ,  0.72774803, -1.27530088, -1.11940418],
#        [ 1.07675941, -0.21182291,  0.74354998,  0.68267565],
#        [-1.03462052,  0.4928553 , -1.27530088, -1.24812416],
#        [-0.78622289,  2.37199719, -1.21922169, -1.37684415],
#        [-0.16522879, -0.68160839,  0.46315403,  0.1677957 ],
#        [-0.16522879, -0.44671565,  0.29491646,  0.1677957 ],
#        [ 1.07675941,  0.4928553 ,  1.13610432,  1.1975556 ],
#        [-0.28942761, -1.3862866 ,  0.12667889, -0.08964428],
#        [ 0.57996413, -0.44671565,  1.08002513,  0.81139564],
#        [-0.9104217 ,  1.66731898, -1.1631425 , -1.24812416],
#        [ 1.07675941,  0.02306982,  1.08002513,  1.58371556],
#        [-1.28301816,  0.02306982, -1.1631425 , -1.24812416],
#        [-0.9104217 ,  1.43242624, -1.21922169, -0.99068419],
#        [ 0.70416295, -0.68160839,  1.08002513,  1.32627558],
#        [ 0.82836177, -0.21182291,  1.02394594,  0.81139564],
#        [ 1.69775351, -0.21182291,  1.19218351,  0.55395566],
#        [ 0.20736767, -0.21182291,  0.6313916 ,  0.81139564],
#        [ 0.70416295, -0.68160839,  1.08002513,  1.1975556 ],
#        [-0.41362643, -1.3862866 ,  0.18275808,  0.1677957 ],
#        [ 1.20095823,  0.25796256,  1.2482627 ,  1.45499557],
#        [ 1.07675941,  0.02306982,  0.57531241,  0.42523567],
#        [-1.15881934,  0.02306982, -1.21922169, -1.37684415],
#        [ 0.33156649, -0.44671565,  0.57531241,  0.29651569],
#        [ 0.82836177,  0.25796256,  0.79962917,  1.06883561],
#        [-1.28301816, -0.21182291, -1.27530088, -1.11940418],
#        [ 2.31874761, -0.68160839,  1.69689622,  1.06883561],
#        [ 0.82836177, -0.21182291,  1.19218351,  1.32627558],
#        [-0.53782525,  1.90221172, -1.10706331, -0.99068419],
#        [-1.5314158 ,  1.19753351, -1.49961764, -1.24812416],
#        [-0.66202407,  1.43242624, -1.21922169, -1.24812416],
#        [ 1.07675941,  0.4928553 ,  1.13610432,  1.71243555],
#        [ 0.20736767, -0.44671565,  0.46315403,  0.42523567],
#        [-0.16522879, -1.3862866 ,  0.74354998,  1.06883561],
#        [ 0.57996413, -0.91650113,  0.68747079,  0.81139564],
#        [-1.03462052,  1.19753351, -1.27530088, -1.24812416],
#        [-1.03462052,  0.96264077, -1.1631425 , -0.73324421],
#        [-1.15881934,  1.19753351, -1.27530088, -1.37684415],
#        [ 0.45576531, -0.68160839,  0.6313916 ,  0.81139564],
#        [-1.77981344, -0.21182291, -1.33138007, -1.24812416],
#        [-0.9104217 ,  0.72774803, -1.21922169, -1.24812416],
#        [ 2.31874761, -0.21182291,  1.36042108,  1.45499557],
#        [ 0.70416295, -0.44671565,  0.35099565,  0.1677957 ],
#        [-0.28942761, -0.21182291,  0.46315403,  0.42523567],
#        [-1.15881934, -1.62117934, -0.20979626, -0.21836426]])

# %%
X_test_standard = standardScaler.transform(X_test)
X_test_standard
# Out:
# array([[ 2.19454879, -0.21182291,  1.64081703,  1.1975556 ],
#        [-1.90401226, -0.21182291, -1.44353845, -1.37684415],
#        [-1.65561462, -1.85607207, -1.33138007, -1.11940418],
#        [-1.40721698,  0.25796256, -1.1631425 , -1.24812416],
#        [-0.41362643,  2.60688993, -1.27530088, -1.24812416],
#        [ 0.82836177, -0.68160839,  0.51923322,  0.42523567],
#        [ 0.45576531, -0.44671565,  0.35099565,  0.1677957 ],
#        [ 1.94615115, -0.68160839,  1.36042108,  0.94011562],
#        [-0.53782525, -0.21182291,  0.46315403,  0.42523567],
#        [-1.15881934, -1.3862866 ,  0.46315403,  0.68267565],
#        [ 0.08316885,  0.25796256,  0.6313916 ,  0.81139564],
#        [-0.16522879, -0.68160839,  0.23883727,  0.1677957 ],
#        [-0.04102997, -0.91650113,  0.79962917,  0.94011562],
#        [ 1.07675941, -1.3862866 ,  1.19218351,  0.81139564],
#        [ 0.33156649, -0.21182291,  0.68747079,  0.81139564],
#        [ 2.31874761,  1.66731898,  1.69689622,  1.32627558],
#        [ 1.32515705,  0.02306982,  0.96786675,  1.1975556 ],
#        [-0.04102997, -0.91650113,  0.23883727, -0.21836426],
#        [-0.28942761, -0.68160839,  0.68747079,  1.06883561],
#        [-0.41362643, -1.85607207,  0.18275808,  0.1677957 ],
#        [ 1.20095823, -0.21182291,  1.02394594,  1.1975556 ],
#        [ 0.45576531, -2.09096481,  0.46315403,  0.42523567],
#        [-0.41362643, -1.62117934,  0.0145205 , -0.21836426],
#        [-0.04102997, -0.91650113,  0.79962917,  0.94011562],
#        [-0.41362643, -1.62117934,  0.0705997 , -0.08964428],
#        [ 0.57996413,  0.4928553 ,  1.30434189,  1.71243555],
#        [-0.41362643,  0.96264077, -1.33138007, -1.24812416],
#        [-1.40721698,  0.25796256, -1.33138007, -1.24812416],
#        [ 1.20095823, -0.68160839,  0.6313916 ,  0.29651569],
#        [-0.04102997, -0.91650113,  0.12667889,  0.03907571],
#        [-0.28942761, -0.21182291,  0.23883727,  0.1677957 ],
#        [-0.16522879, -1.15139386, -0.09763788, -0.21836426],
#        [-0.53782525,  1.43242624, -1.21922169, -1.24812416],
#        [ 0.20736767,  0.72774803,  0.46315403,  0.55395566],
#        [-1.77981344, -0.44671565, -1.27530088, -1.24812416],
#        [-0.28942761, -0.44671565, -0.04155869,  0.1677957 ],
#        [ 2.56714525,  1.66731898,  1.52865865,  1.06883561],
#        [-1.03462052,  0.72774803, -1.21922169, -1.24812416]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_clf = KNeighborsClassifier(n_neighbors=3)

# %%
knn_clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
knn_clf.score(X_test_standard, y_test)
# Out:
# 0.9210526315789473

# %%
knn_clf.score(X_test, y_test)
# Out:
# 0.34210526315789475
